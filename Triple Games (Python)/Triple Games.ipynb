# %% [markdown]
# #Project

# %%
def Rock(S):
  import random
  choices = ["Rock","Paper","Scissors","Love","Money"]
  computer = random.choice(choices)
  player = False
  cpu_score = 0
  player_score = 0
  
  while True:
    print(color.PURPLE + color.BOLD + "🧐 Rock, Paper, Scissors, Love or Money and E or e to exit. 🤪\n" + color.END)
    player = input("").capitalize()
    if player == computer:
      print("Tie! 😌")
    elif player == "Rock":
      if computer == "Paper":
        print("You lose! 😉", computer,"covers", player)
        cpu_score+=1
      elif computer == "Love":
        print("You lose! 😛", computer,"conquers", player)
        cpu_score+=1
      elif computer == "Money":
        print("You win! 😘", player,"Overlay", computer)
        player_score+=1  
      else:
        print("You win! 😎", player,"smashes", computer)
        player_score+=1
    elif player == "Paper":
      if computer == "Scissors":
        print("You lose! 😢", computer, "cut", player)
        cpu_score+=1
      elif computer == "Love":
        print("You lose! 🥴", computer,"conquers", player)
        cpu_score+=1 
      else:
        print("You win! 😈", player, "covers", computer)
        player_score+=1
    elif player == "Scissors":
      if computer == "Rock":
        print("You lose... 👅",computer, "smashes", player)
        cpu_score+=1  
      else:
        print("You win! 🖕🏻",player, "cut", computer)
        player_score+=1
    elif player == "Love":
      if computer == "Scissors":
        print("You lose... 😭",computer, "Cut off from", player)
        cpu_score+=1
      elif computer == "Money":
        print("You lose! 🤣", computer,"buy", player)
        cpu_score+=1   
      else:
        print("Love win! 😘💚",player, "conquers", computer)
        player_score+=1
    elif player == "Money":
      if computer == "Scissors":
        print("You lose... 🐔",computer, "Cut the", player)
        cpu_score+=1
      elif computer == "Paper":
        print("You Tie! 😫", computer,"like a", player)
      elif computer == "Rock":
        print("You lose! 🐔🐔", computer,"Overlay", player)
        cpu_score+=1   
      else:
        print("Money can buy everyting! 💸💸💸",player, "buy 🏄🏻‍♂️", computer)
        player_score+=1

    #SP
    elif player_score>=5:
      print(color.DARKCYAN + color.BOLD + "\n🎉🎉🎉 WOW u won all 5 rounds, we have a special game for you.  Are you interested? (Y/N) 😛\n" + color.END)
      print(f"\t Now score player : {player_score} \n")
      RR = input()
      if RR.lower() == 'y':
        Tryemo(E)
        break
      else:
        print (color.RED + "🥺 You missed our special game. 😭\n" + color.END)
        Rock(S)
      break
      return
        

    elif player =='E' or player.lower() == 'e':
      print("Final scores:")
      print(f"CPU:{cpu_score}")
      print(f"Player:{player_score}")
      print(color.BOLD + "Do you want to play again? (Y/N) 🥺\n" + color.END)
      R = input("")
      if R.lower() == 'y':
          Rock(S)
      break
      return
    else:
      print(color.RED + "That's not a valid play. Check your spelling! 😒" + color.END)
    computer = random.choice(choices)    



def Tryemo(E):

  while True:
    print (color.RED + color.BOLD + "Welcome to Emoji game 👅\n" + color.END)
    plstry = input("Do u know how to enter Emoji (😀) ?\n \t> If u already know, please try enter 😀 to start the game.\n \t> If you don't know how to input Emo, I will teach you now. (Pls. input N)\n")
    if plstry == '😀':
      print (color.BLUE + "Good" + color.END)
      Emoji(F)
      break
    if plstry == 'n' or plstry == 'N':
      plstryy = input("\nHow to use Emoji 😀\n >>>WINDOWN<<<\n \tWindows logo key + (period).\n >>>MAC OS<<<\n \tControl + Command + Spacebar.\n\n Please try enter 😀 to start the game again or N to Exit\n")
      if plstryy == '😀':
          Emoji(F)
          break
      elif plstryy == 'n' or plstryy == 'N':
        print (color.RED + "Buy" + color.END)
        break
        return

def Emoji(F):
  import random
  choices = ["😎","💔","😡","😍","🤑"]
  computer = random.choice(choices)
  player = False
  cpu_score = 0
  player_score = 0

  while True:
    print (color.PURPLE + color.BOLD + "Pls. input Emoji : 😎, 💔, 😡, 😍 or 🤑 and E or e to exit. 🤪\n" + color.END)
    player = input("").capitalize()
    if player == computer:
      print("Tie! 😌")
    elif player == "😎":
      if computer == "💔":
        print("You lose! 😉", computer,"covers", player)
        cpu_score+=1
      elif computer == "😍":
        print("You lose! 😛", computer,"conquers", player)
        cpu_score+=1
      elif computer == "🤑":
        print("You win! 😘", player,"Overlay", computer)
        player_score+=1  
      else:
        print("You win! 😎", player,"smashes", computer)
        player_score+=1
    elif player == "💔":
      if computer == "😡":
        print("You lose! 😢", computer, "cut", player)
        cpu_score+=1
      elif computer == "😍":
        print("You lose! 🥴", computer,"conquers", player)
        cpu_score+=1 
      else:
        print("You win! 😈", player, "covers", computer)
        player_score+=1
    elif player == "😡":
      if computer == "😎":
        print("You lose... 👅",computer, "smashes", player)
        cpu_score+=1  
      else:
        print("You win! 🖕🏻",player, "cut", computer)
        player_score+=1
    elif player == "😍":
      if computer == "😡":
        print("You lose... 😭",computer, "Cut off from", player)
        cpu_score+=1
      elif computer == "🤑":
        print("You lose! 🤣", computer,"buy", player)
        cpu_score+=1   
      else:
        print("😍 win! 😘💚",player, "conquers", computer)
        player_score+=1
    elif player == "🤑":
      if computer == "😡":
        print("You lose... 🐔",computer, "Cut the", player)
        cpu_score+=1
      elif computer == "💔":
        print("You Tie! 😫", computer,"like a", player)
      elif computer == "😎":
        print("You lose! 🐔🐔", computer,"Overlay", player)
        cpu_score+=1   
      else:
        print("🤑 can buy everyting! 💸💸💸",player, "buy 🏄🏻‍♂️", computer)
        player_score+=1

        

    elif player =='E' or player.lower() == 'e' or player == '🖕🏻':
      print("Final scores:")
      print(f"CPU:{cpu_score}")
      print(f"Player:{player_score}")
      R = input('Do you want to play again? (Y/N) 🥺\n')
      if R.lower() == 'y':
          Emoji(S)
      break
      return
    else:
      print(color.RED + "That's not a valid play. Check your spelling! 😒" + color.END)
    computer = random.choice(choices)    


def XO(X):
  board = [' ' for x in range(10)]

  def insertLetter(letter, pos):
      board[pos] = letter

  def spaceIsFree(pos):
      return board[pos] == ' '

  def printBoard(board):
      print('   |   |')
      print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
      print('   |   |')
      print('-----------')
      print('   |   |')
      print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
      print('   |   |')
      print('-----------')
      print('   |   |')
      print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
      print('   |   |')
    
  def isWinner(bo, le):
      return (bo[7] == le and bo[8] == le and bo[9] == le) or (bo[4] == le and bo[5] == le and bo[6] == le) or(bo[1] == le and bo[2] == le and bo[3] == le) or(bo[1] == le and bo[4] == le and bo[7] == le) or(bo[2] == le and bo[5] == le and bo[8] == le) or(bo[3] == le and bo[6] == le and bo[9] == le) or(bo[1] == le and bo[5] == le and bo[9] == le) or(bo[3] == le and bo[5] == le and bo[7] == le)

  def playerMove():
      run = True
      while run:
          move = input('Please select a position to place an \'X\' (1-9):\n ')
          try:
              move = int(move)
              if move > 0 and move < 10:
                  if spaceIsFree(move):
                      run = False
                      insertLetter('X', move)
                  else:
                      print('Sorry, this space is occupied! 😢')
              else:
                  print('Please type a number within the range! 🤬')
          except:
              print('Please type a number! 😤')
            

  def compMove():
      possibleMoves = [x for x, letter in enumerate(board) if letter == ' ' and x != 0]
      move = 0

      for let in ['O', 'X']:
          for i in possibleMoves:
              boardCopy = board[:]
              boardCopy[i] = let
              if isWinner(boardCopy, let):
                  move = i
                  return move

      cornersOpen = []
      for i in possibleMoves:
          if i in [1,3,7,9]:
              cornersOpen.append(i)
            
      if len(cornersOpen) > 0:
          move = selectRandom(cornersOpen)
          return move

      if 5 in possibleMoves:
          move = 5
          return move

      edgesOpen = []
      for i in possibleMoves:
          if i in [2,4,6,8]:
              edgesOpen.append(i)
            
      if len(edgesOpen) > 0:
          move = selectRandom(edgesOpen)
        
      return move

  def selectRandom(li):
      import random
      ln = len(li)
      r = random.randrange(0,ln)
      return li[r]
    

  def isBoardFull(board):
      if board.count(' ') > 1:
          return False
      else:
          return True

  def main():
      print(color.GREEN + color.BOLD + "Welcome to Tic Tac Toe! 😉" + color.END)
      printBoard(board)

      while not(isBoardFull(board)):
          if not(isWinner(board, 'O')):
              playerMove()
              printBoard(board)
          else:
              print('Sorry, O\'s won this time!')
              k = input('Do you want to play again? (Y/N) 😢\n')
              if k.lower() == 'y' or k.lower== 'yes':
                XO(X)
              break

          if not(isWinner(board, 'X')):
              move = compMove()
              if move == 0:
                  print('Tie Game!')
                  k = input('Do you want to play again? (Y/N) 😢')
                  if k.lower() == 'y' or k.lower== 'yes':
                    XO(X)
                  break
              else:
                  insertLetter('O', move)
                  print('Computer placed an \'O\' in position', move , ':')
                  printBoard(board)
          else:
              print('X\'s won this time! Good Job! 😎')
              k = input('Do you want to play again? (Y/N) 😬\n')
              if k.lower() == 'y' or k.lower== 'yes':
                XO(X)
              break

      if isBoardFull(board):
          print('END Game! 🤗')

  while True:
      a = input('Do you want to play XO? (Y/N) 🥺\n')
      if a.lower() == 'y' or a.lower == 'yes':
          board = [' ' for x in range(10)]
          print('-----------------------------------')
          main()
      else:
          break

def Twenty_one(T):
  # Python code to play 21 Number game
  
# returns the nearest multiple to 4
 def nearestMultiple(num):
    if num >= 4:
        near = num + (4 - (num % 4))
    else:
        near = 4
    return near
  

# checks whether the numbers are consecutive
 def check(xyz):
    i = 1
    while i<len(xyz):
        if (xyz[i]-xyz[i-1])!= 1:
            return False
        i = i + 1
    return True
  
# starts the game
 def start1():
    xyz = []
    last = 0
    print(color.BLUE + color.BOLD + "\n welcome to 21 Game. 🥴" + color.END)
    while True:
        print("\tEnter 'F' or 'f' to take the first chance.")
        print("\tEnter 'S' or 's' to take the second chance.")
        print("\tEnter 'Q' or 'q' to quit")
        chance = input('> ')
          
        # player takes the first chance
        if chance.lower() == 'f':
            while True:
                if last == 20:
                    print ("You Lose 😛")
                    return False
                else:
                    print ("\nYour Turn. 😎")
                    print ("\nHow many numbers do you wish to enter?")
                    c = True
                    while c :
                        inp = input('> ')
                        try : 
                          inp = int(inp)  
                          if inp > 0 and inp <= 3:
                            comp = 4 - inp
                            c = False
                          else:
                            print ("Wrong input. You are disqualified from the game. 🤬")
                            print ("You lose! 😛")
                            return False
                        except:
                          print ("Please enter number 1️⃣2️⃣3️⃣")
              
                    i, j = 1, 1
  
                    print ("Now enter the values")
                    while i <= inp:
                      v = True
                      while v :
                        a = input('> ')
                        try : 
                          a = int(a)
                          xyz.append(a)
                          i = i + 1
                          v = False
                        except:
                          print ("Please enter number 1️⃣2️⃣3️⃣")
                    
                      
                    # store the last element of xyz.
                    last = xyz[-1] 
                      
                    # checks whether the input 
                    # numbers are consecutive
                    if check(xyz) == True: 
                        if last == 21:
                            print ("You lose! 🤣")
                            return False
                              
                        else:
                            #"Computer's turn."
                            while j <= comp:
                                xyz.append(last + j)
                                j = j + 1
                            print ("Order of inputs after computer's turn is: ")
                            print (xyz)
                            last = xyz[-1]
                            if last >= 21:
                              print ("\n\nCONGRATULATIONS 🎉🎉🎉")
                              print ("YOU WON 🧸")
                              return False
                    else:
                        print ("\n🤦🏻‍♀️ You did not input consecutive integers. 1️⃣2️⃣3️⃣🤷🏻‍♀️")
                        print ("You Lose 😛😎")
                        return False
                          
        # player takes the second chance
        elif chance.lower() == 's':
            comp = 1
            last = 0
            while last < 20:
                #"Computer's turn"
                j = 1
                while j <= comp:
                    xyz.append(last + j)
                    j = j + 1
                print ("Order of inputs after computer's turn is:")
                print (xyz)
                if xyz[-1] == 20:   
                    print ("You Lose 😛")
                    return False
                else:
                    print ("\nYour turn. 😌")
                    print ("\nHow many numbers do you wish to enter? 🙃")
                    h = True
                    while h :
                        inp = input('> ')
                        try : 
                          inp = int(inp)
                          i = 1
                          h = False                      
                        except:
                          print ("Please enter number 1️⃣2️⃣3️⃣")
                    print ("Enter your values")
                    while i <= inp:
                      v = True
                      while v :
                         b = input('> ')
                         try : 
                          b = int(b)
                          xyz.append(b)
                          i = i + 1
                          v = False
                         except:
                          print ("Please enter number 1️⃣2️⃣3️⃣")
                       
                    last = xyz[-1]
                    if check(xyz) == True:
                        # print (xyz)
                        near = nearestMultiple(last)
                        comp = near - last
                        if comp == 4:
                            comp = 3
                        else:
                            comp = comp
                    else:
                        # if inputs are not consecutive
                        # automatically disqualified
                        print ("\n🤦🏻‍♀️ You did not input consecutive integers. 1️⃣2️⃣3️⃣🤷🏻‍♀️")
                        # print ("You are disqualified from the game.")
                        return False
                                    
            print (color.BLUE + "\n\nCONGRATULATIONS 🎉🎉🎉" + color.END)
            print (color.BLUE + "YOU WON 🧸" + color.END)
            break 
        elif chance.lower() == 'q':
            break
        else:
            print (color.RED + "Wrong Choice! 😌" + color.END)
                          
          
     
 while True:
        print (color.BOLD + "Player 2 is Computer. 💩" + color.END)
        print("\tDo you want to play the 2️⃣1️⃣ number game? (Yes ☺️ / No 😕)")
        ans = input('> ')
        if ans.lower() == 'y' or ans == 'yes' or ans.lower() == 'yes':
            start1()
        else:
            print ("Do you want quit the game?(Yes ☺️ / No 🥺)")
            nex = input('> ')
            if nex.lower() == 'y' or nex == 'yes' or nex.lower() == 'yes':
                print ("You are quitting the game... 😮‍💨")             
                break
                
            elif nex.lower() == 'n' or nex == 'no' or nex.lower() == 'no':
                print ("Continuing... 😘")
            else:
                print ("Wrong Choice!")
  
  ##color.PURPLE + color.BOLD + "\n👽 Do you want to play Game ? 👾🤖" + color.END
            
                
E = ""
F = ""
S = ""
X = ""
T = ""
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
while True:
  print(color.BLUE + color.BOLD + "\n👽 Do you want to play Game ? 👾🤖" + color.END)
  answer = input("\t S : 😡(Emoji) Level 1 (Easy) 💪🏻✊🏻\n\t X : XO Level 2 (Medium)❌⭕️\n\t T : Twenty-one Level 3(Hard)2️⃣1️⃣\n\t N : Quit 😔\n")
  if answer.lower() == 's':
      S == True
      Rock(S)
  if answer.lower() == 'x':
      X == True
      XO(X)
  if answer.lower() == 't':
      T == True
      Twenty_one(T)      
  if answer.lower() == 'n':
      break
# Out:
# 👽 Do you want to play Game ? 👾🤖
# 	 S : 😡(Emoji) Level 1 (Easy) 💪🏻✊🏻
# 	 X : XO Level 2 (Medium)❌⭕️
# 	 T : Twenty-one Level 3(Hard)2️⃣1️⃣
# 	 N : Quit 😔
# t
# Player 2 is Computer. 💩
# 	Do you want to play the 2️⃣1️⃣ number game? (Yes ☺️ / No 😕)
# > y
#
#  welcome to 21 Game. 🥴
# 	Enter 'F' or 'f' to take the first chance.
# 	Enter 'S' or 's' to take the second chance.
# 	Enter 'Q' or 'q' to quit
# > s
# Order of inputs after computer's turn is:
# [1]
#
# Your turn. 😌
#
# How many numbers do you wish to enter? 🙃
# > 5
# Enter your values
# > 4
# > 2
# > 1
# > 1
# > 1
#
# 🤦🏻‍♀️ You did not input consecutive integers. 1️⃣2️⃣3️⃣🤷🏻‍♀️
# Player 2 is Computer. 💩
# 	Do you want to play the 2️⃣1️⃣ number game? (Yes ☺️ / No 😕)
# > y
#
#  welcome to 21 Game. 🥴
# 	Enter 'F' or 'f' to take the first chance.
# 	Enter 'S' or 's' to take the second chance.
# 	Enter 'Q' or 'q' to quit
# > f
#
# Your Turn. 😎
#
# How many numbers do you wish to enter?
# > 1
# Now enter the values
# > 2
# ...

# %% [markdown]
# #อ้างอิง
#
# https://www.geeksforgeeks.org/21-number-game-in-python/
#
# https://levelup.gitconnected.com/21-python-mini-projects-with-codes-c4126e4131e4
#
# https://www.techwithtim.net/tutorials/python-programming/tic-tac-toe-tutorial/
